# %%
import pandas as pd

# %%
data = pd.read_csv('netflix_titles.csv')

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data[["rating"]]
# Out:
#      rating
# 0     PG-13
# 1     TV-MA
# 2     TV-MA
# 3     TV-MA
# 4     TV-MA
# ...     ...
# 8802      R
# 8803  TV-Y7
# 8804      R
# 8805     PG
# 8806  TV-14
#
# [8807 rows x 1 columns]

# %%
data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
data[data["country"] == "United States"]
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 9        s10    Movie          The Starling   Theodore Melfi
# 15       s16  TV Show     Dear White People              NaN
# 27       s28    Movie             Grown Ups     Dennis Dugan
# 28       s29    Movie            Dark Skies    Scott Stewart
# ...      ...      ...                   ...              ...
# 8791   s8792    Movie           Young Adult    Jason Reitman
# 8793   s8794    Movie  Yours, Mine and Ours     Raja Gosnell
# 8802   s8803    Movie                Zodiac    David Fincher
# 8804   s8805    Movie            Zombieland  Ruben Fleischer
# 8805   s8806    Movie                  Zoom     Peter Hewitt
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# ...

# %%
len(data[data["country"] == "United States"]) # Total number of web series make in america
# Out:
# 2818

# %%
data[(data["country"] == "United States") & (data["type"] == "Movie")]
# Out:
#      show_id   type                 title          director  \
# 0         s1  Movie  Dick Johnson Is Dead   Kirsten Johnson
# 9        s10  Movie          The Starling    Theodore Melfi
# 27       s28  Movie             Grown Ups      Dennis Dugan
# 28       s29  Movie            Dark Skies     Scott Stewart
# 41       s42  Movie                  Jaws  Steven Spielberg
# ...      ...    ...                   ...               ...
# 8791   s8792  Movie           Young Adult     Jason Reitman
# 8793   s8794  Movie  Yours, Mine and Ours      Raja Gosnell
# 8802   s8803  Movie                Zodiac     David Fincher
# 8804   s8805  Movie            Zombieland   Ruben Fleischer
# 8805   s8806  Movie                  Zoom      Peter Hewitt
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# ...

# %%
# Total movie make in america 

len(data[(data["country"] == "United States") & (data["type"] == "Movie")])
# Out:
# 2058

# %%
data[data["director"] == "Kirsten Johnson"]
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description
# 0  As her father nears the end of his life, filmm...

# %%
data["director"].count()
# Out:
# 6173

# %%
len(data[data["director"].duplicated()])
# Out:
# 4278

# %%
data[data["director"] =="Avadhoot Gupte"]
# Out:
#      show_id   type  title        director  \
# 7512   s7513  Movie  Morya  Avadhoot Gupte
# 8799   s8800  Movie  Zenda  Avadhoot Gupte
#
#                                                    cast country  \
# 7512  Santosh Juvekar, Chinmay Mandlekar, Pari Telan...   India
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...   India
#
#              date_added  release_year rating duration  \
# 7512  February 15, 2018          2011  TV-14  121 min
# 8799  February 15, 2018          2009  TV-14  120 min
#
#                          listed_in  \
# 7512  Dramas, International Movies
# 8799  Dramas, International Movies
#
#                                             description
# 7512  Two communities in Mumbai get a final chance t...
# 8799  A change in the leadership of a political part...

# %%
data.iloc[1645]
# Out:
# show_id                                                     s1646
# type                                                        Movie
# title                          Larry the Cable Guy: Remain Seated
# director                                         Brian Volk-Weiss
# cast                                          Larry the Cable Guy
# country                                             United States
# date_added                                      November 26, 2020
# release_year                                                 2020
# rating                                                      TV-14
# duration                                                   68 min
# listed_in                                         Stand-Up Comedy
# description     With his signature call to "Git-R-Done," Larry...
# Name: 1645, dtype: object

# %%
data["country"]
# Out:
# 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object

# %%
data[data["country"] == "India"]
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %%
len(data[data["country"] == "India"])
# Out:
# 972

# %%
d = data[data["country"] == "India"]

# %%
d[["director"]]
# Out:
#                      director
# 4                         NaN
# 24                 S. Shankar
# 39                        NaN
# 50                        NaN
# 66                        NaN
# ...                       ...
# 8773             Kedar Shinde
# 8775                      NaN
# 8798  Chandra Prakash Dwivedi
# 8799           Avadhoot Gupte
# 8806              Mozez Singh
#
# [972 rows x 1 columns]

# %%
len(d[d["director"].duplicated()])
# Out:
# 326

# %%
d[d["director"] == "Chandra Prakash Dwivedi"]
# Out:
#      show_id   type     title                 director  \
# 8798   s8799  Movie  Zed Plus  Chandra Prakash Dwivedi
#
#                                                    cast country  \
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...   India
#
#              date_added  release_year rating duration  \
# 8798  December 31, 2019          2014  TV-MA  131 min
#
#                                    listed_in  \
# 8798  Comedies, Dramas, International Movies
#
#                                             description
# 8798  A philandering small-town mechanic's political...
