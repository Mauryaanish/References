# %%
import pandas as pd
import numpy as np
import json
from glob import glob
import pymongo

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data = glob(r'D:\option_data\data/*')

# %%
index_data = data[0]
option_data = data[1]

# %%
with open (index_data , 'r') as file:
    data = file.read()

# %%
pip install memory-profiler
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from memory_profiler import profile

# %%
pip install dask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install modin
# Out:
# ...
#   Obtaining dependency information for modin from https://files.pythonhosted.org/packages/7e/73/837d9d6d402abf3fde4f6584a505447eee724fd3575f78ffde879b0f6cdf/modin-0.26.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pandas<2.2,>=2.1 from https://files.pythonhosted.org/packages/11/17/fb1a34f3e73debbc2fd15a01ea17eaab3717943d08463ff4979a4f024b3f/pandas-2.1.4-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.1/1.1 MB 1.6 MB/s eta 0:00:01
#    --------- ------------------------------ 0.3/1.1 MB 2.8 MB/s eta 0:00:01
#    ------------------ --------------------- 0.5/1.1 MB 3.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.8/1.1 MB 4.3 MB/s eta 0:00:01
#    -------------------------------------- - 1.1/1.1 MB 5.0 MB/s eta 0:00:01
# ...

# %%
import dask.dataframe as dd

# %%
df = dd.read_csv(option_data)

# %%
with open (option_data , 'r') as file:
    data = file.read()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[18], line 2
#       1 with open (option_data , 'r') as file:
# ----> 2     data = file.read()
#
# MemoryError:

# %%
pd.read_csv(option_data)
