# %%
# practice sales compuny data and make a some graph which quater compuny do very well and make profit

# %%
pip install cufflinks
# Out:
# ...
#
# ...

# %%
pip install chart_studio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import cufflinks as cf
import seaborn as sea

# %%
df = pd.read_csv("statsfinal.csv")

# %%
df
# Out:
#       Unnamed: 0        Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2  \
# 0              0  13-06-2010  5422  3725   576   907  17187.74  23616.50
# 1              1  14-06-2010  7047   779  3578  1574  22338.99   4938.86
# 2              2  15-06-2010  1572  2082   595  1145   4983.24  13199.88
# 3              3  16-06-2010  5657  2399  3140  1672  17932.69  15209.66
# 4              4  17-06-2010  3668  3207  2184   708  11627.56  20332.38
# ...          ...         ...   ...   ...   ...   ...       ...       ...
# 4595        4595  30-01-2023  2476  3419   525  1359   7848.92  21676.46
# 4596        4596  31-01-2023  7446   841  4825  1311  23603.82   5331.94
# 4597        4597  01-02-2023  6289  3143  3588   474  19936.13  19926.62
# 4598        4598  02-02-2023  3122  1188  5899   517   9896.74   7531.92
# 4599        4599  03-02-2023  1234  3854  2321   406   3911.78  24434.36
#
#           S-P3      S-P4
# 0      3121.92   6466.91
# 1     19392.76  11222.62
# ...

# %%
df.rename(columns = {"Unnamed: 0" : "Index"})
# Out:
#       Index        Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2      S-P3  \
# 0         0  13-06-2010  5422  3725   576   907  17187.74  23616.50   3121.92
# 1         1  14-06-2010  7047   779  3578  1574  22338.99   4938.86  19392.76
# 2         2  15-06-2010  1572  2082   595  1145   4983.24  13199.88   3224.90
# 3         3  16-06-2010  5657  2399  3140  1672  17932.69  15209.66  17018.80
# 4         4  17-06-2010  3668  3207  2184   708  11627.56  20332.38  11837.28
# ...     ...         ...   ...   ...   ...   ...       ...       ...       ...
# 4595   4595  30-01-2023  2476  3419   525  1359   7848.92  21676.46   2845.50
# 4596   4596  31-01-2023  7446   841  4825  1311  23603.82   5331.94  26151.50
# 4597   4597  01-02-2023  6289  3143  3588   474  19936.13  19926.62  19446.96
# 4598   4598  02-02-2023  3122  1188  5899   517   9896.74   7531.92  31972.58
# 4599   4599  03-02-2023  1234  3854  2321   406   3911.78  24434.36  12579.82
#
#           S-P4
# 0      6466.91
# ...

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot(x = "Q-P1" , y = "S-P1" , xTitle = "Unit Sales" , yTitle = "Revenue" , kind = "bar")
# Out:
# <div>                            <div id="ea74dabc-6c0f-4ede-8017-8afe3e291721" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x = "Q-P2" , y = "S-P2" , xTitle = "Unit Sales" , yTitle = "Revenue" )
# Out:
# <div>                            <div id="87e31c21-63a3-4eda-83c3-1bd5ca0c0b42" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x = "Q-P3" , y = "S-P3" , xTitle = "Unit Sales" , yTitle = "Revenue" )
# Out:
# <div>                            <div id="0ac3fde5-5df0-4406-a03a-2286d06fbe44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1 =df.iloc[0]
df1
# Out:
# Unnamed: 0             0
# Date          13-06-2010
# Q-P1                5422
# Q-P2                3725
# Q-P3                 576
# Q-P4                 907
# S-P1            17187.74
# S-P2             23616.5
# S-P3             3121.92
# S-P4             6466.91
# Name: 0, dtype: object

# %%
df1[["Q-P1" , "S-P1"]].plot(kind = "bar" , title = "Q1 Sale and Revenue ")
# Out:
# <AxesSubplot:title={'center':'Q1 Sale and Revenue '}>

# %%
df1[["Q-P2" , "S-P2"]].plot(kind = "bar" , title = "Q2 Sale and Revenue ")
# Out:
# <AxesSubplot:title={'center':'Q2 Sale and Revenue '}>

# %%
df1[["Q-P3" , "S-P3"]].plot(kind = "bar" , title = "Q3 Sale and Revenue ")
# Out:
# <AxesSubplot:title={'center':'Q3 Sale and Revenue '}>

# %%
df2 = df.iloc[4596]

# %%
df2[["Q-P1" , "S-P1"]].plot(kind = "bar" , title = "Q1 Sale and Revenue ")
# Out:
# <AxesSubplot:title={'center':'Q1 Sale and Revenue '}>

# %%
df2[["Q-P2" , "S-P2"]].plot(kind = "bar" , title = "Q2 Sale and Revenue ")
# Out:
# <AxesSubplot:title={'center':'Q2 Sale and Revenue '}>

# %%
df2[["Q-P1" ,"S-P1" , "Q-P2" ,"S-P2", "Q-P3" , "S-P3"]].plot(kind = "bar" , title = "Adani  Sale and Revenue ")
# Out:
# <AxesSubplot:title={'center':'Adani  Sale and Revenue '}>

# %%
df2
# Out:
# Unnamed: 0          4596
# Date          31-01-2023
# Q-P1                7446
# Q-P2                 841
# Q-P3                4825
# Q-P4                1311
# S-P1            23603.82
# S-P2             5331.94
# S-P3             26151.5
# S-P4             9347.43
# Name: 4596, dtype: object

# %%
df3 = pd.DataFrame({"Open" : [25 , 23 , 28 , 55 , 40.1 , 63.1 , 85] , "High" : [32.3 , 39 , 34.6 , 55 , 61.6 , 80, 85] , "Low" : [23.5 , 23 , 20 , 10 , 5.6 ,63.05 , 54] , "Close" : [28 , 35 , 34.6 , 10 , 58.6 , 76.9 , 56.8]} , index = ["11-12,2023" , "12-12-2023" , "13-12-2023" , "14-12-2023" , "15-12-2023" , "18-12-2013" , "19-12-2023"])

# %%
df3
# Out:
#             Open  High    Low  Close
# 11-12,2023  25.0  32.3  23.50   28.0
# 12-12-2023  23.0  39.0  23.00   35.0
# 13-12-2023  28.0  34.6  20.00   34.6
# 14-12-2023  55.0  55.0  10.00   10.0
# 15-12-2023  40.1  61.6   5.60   58.6
# 18-12-2013  63.1  80.0  63.05   76.9
# 19-12-2023  85.0  85.0  54.00   56.8

# %%
df3.iplot(kind = "candle"  , yTitle = "Price in Billion" , xTitle = "Date" , title  = "Adani Enterprise")
